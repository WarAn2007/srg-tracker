# %% [markdown]
# # 03 — Inference demo
#
# Demonstation of forecasting a weekly-records. The values are training and can not be used in automatic academic decision.
#
# ---
# Try to chage week number, attendace and current grade. DO NOT ADD `final_course_score`, `course_outcome` or `final_exam`, they are future information and occurs leakage.

# %%
from pathlib import Path
import sys
ROOT = Path.cwd() if (Path.cwd() / 'src').exists() else Path.cwd().parent
sys.path.insert(0, str(ROOT))

from src.inference import predict_record

student_week = {
    'course_id': 'ML201',
    'semester': 1,
    'week': 8,
    'attendance_rate_to_date': 75.0,
    'average_weekly_grade_to_date': 67.0,
    'average_assignment_score_to_date': 64.0,
    'average_quiz_score_to_date': 69.0,
    'mean_submission_delay_days_to_date': 0.8,
    'corrections_count_to_date': 1,
    'assignments_completed_to_date': 2,
    'quizzes_completed_to_date': 3,
    'midterm_score_available': 66.0,
}
predict_record(student_week)
