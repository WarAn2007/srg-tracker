# %% [markdown]
# # 04 — Final held-out test evaluation
#
# Result are based on the best model. Test split wasn't participating for evaluation of algorithms.

# %%
from pathlib import Path
import sys
ROOT = Path.cwd() if (Path.cwd() / 'src').exists() else Path.cwd().parent
sys.path.insert(0, str(ROOT))

import pandas as pd
from src.config import METRICS_DIR

pd.read_csv(METRICS_DIR / 'final_test_metrics.csv')

# %%
pd.read_csv(METRICS_DIR / 'score_error_by_week.csv')

# %% [markdown]
# More detailed results stores in - `reports/metrics/`, graphs in - `reports/figures/`.
